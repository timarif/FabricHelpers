# %% [markdown]
# # Cross-workspace sample

# %%
src = "abfss://22222222-2222-2222-2222-222222222222@onelake.dfs.fabric.microsoft.com/33333333-3333-3333-3333-333333333333/Files/data.parquet"
df = spark.read.parquet(src)
df.write.mode("overwrite").parquet("abfss://44444444-4444-4444-4444-444444444444@onelake.dfs.fabric.microsoft.com/55555555-5555-5555-5555-555555555555/Files/out")
