# %% [markdown]
# # Clean sample
#
# This notebook only references benign URLs.

# %%
print("hello world")
x = sum(range(10))
# docs: https://docs.python.org/3/library/sum.html

# %%
import math
print(math.pi)
